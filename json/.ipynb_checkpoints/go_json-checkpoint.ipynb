// %%
import(
    "encoding/json"
    "fmt"
    "io/ioutil"
)

// %%
jsonfile,err:=ioutil.ReadFile("Documents/learning_go/json/64KB.json")
if err!=nil{
    fmt.Println("Error reading file",err)
}

// %%
jsonfile
// Out:
// [91 10 32 32 123 10 32 32 32 32 34 110 97 109 101 34 58 32 34 65 100 101 101 108 32 83 111 108 97 110 103 105 34 44 10 32 32 32 32 34 108 97 110 103 117 97 103 101 34 58 32 34 83 105 110 100 104 105 34 44 10 32 32 32 32 34 105 100 34 58 32 34 86 53 57 79 70 57 50 89 70 54 50 55 72 70 89 48 34 44 10 32 32 32 32 34 98 105 111 34 58 32 34 68 111 110 101 99 32 108 111 98 111 114 116 105 115 32 101 108 101 105 102 101 110 100 32 99 111 110 100 105 109 101 110 116 117 109 46 32 67 114 97 115 32 100 105 99 116 117 109 32 100 111 108 111 114 32 108 97 99 105 110 105 97 32 108 101 99 116 117 115 32 118 101 104 105 99 117 108 97 32 114 117 116 114 117 109 46 32 77 97 101 99 101 110 97 115 32 113 117 105 115 32 110 105 115 105 32 110 117 110 99 46 32 78 97 109 32 116 114 105 115 116 105 113 117 101 32 102 101 117 103 105 97 116 32 101 115 116 32 118 105 116 97 101 32 109 111 108 108 105 115 46 32 77 97 101 99 101 110 97 115 32 113 117 105 115 32 110 105 115 105 32 110 117 110 99 46 34 44 10 32
// ...

// %%
var data map[string]interface{}
err=json.Unmarshal(jsonfile,&data)

// %%
data
// Out:
// map[]

// %%
err
// Out:
// json: cannot unmarshal array into Go value of type map[string]interface {}
